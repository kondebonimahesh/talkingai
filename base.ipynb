# %% [markdown]
# <a href="https://colab.research.google.com/github/kondebonimahesh/talkingai/blob/master/base.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install PyTorch
# !pip install torch torchvision torchaudio

# Install Transformers and Coqui TTS
# !pip install transformers coqui-tts soundfile

# %%
from TTS.api import TTS
import IPython.display as ipd

# Initialize TTS model
model_name = "tts_models/en/ljspeech/tacotron2-DDC"
tts = TTS(model_name)

# Text to be spoken
text = "Hello! This is a test of the text-to-speech model in Google Colab created by mahesh the king."

# Generate speech
audio_path = "output.wav"
tts.tts_to_file(text=text, file_path=audio_path)

# Play the audio in Colab
ipd.Audio(audio_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
